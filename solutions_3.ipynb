# %% [markdown]
# ## 3. Визуализация данных

# %% [markdown]
# ## 1. Визуализация данных и библиотека matplotlib

# %% [markdown]
# ### Задание 1.1

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = np.linspace(0, 10, 1000)
y_1_data = np.sin(x_data)

plt.plot(x_data, y_1_data, color='r', linewidth = '1.0')
plt.grid('g--', linewidth= '0.8')


plt.xlabel('x_data')
plt.ylabel('y_data')
plt.title('function')

plt.show()

# %% [markdown]
# Задание 1.2

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = np.linspace(0, 10, 100)
y_data = np.cos(x_data) 

plt.scatter(x_data, y_data, color='lightblue', marker = '.')
plt.grid('g--', linewidth= '0.8')


plt.xlabel('x_data')
plt.ylabel('y_data')
plt.title('function')

plt.show()

# %% [markdown]
# Задание 1.3

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

heights = [1]
ages = [1]

fig, ((ax1, ax2),(ax3, ax4),(ax5, ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(8, 4))


x_data = [random.randint(0, 100) for x in range(100)]

ax1.hist(x_data, bins = 10, color='green')
ax2.hist(x_data, bins = 30, color='red')
ax3.hist(x_data, bins = 40, color='blue')
ax4.hist(x_data, bins = 50, color='pink')
ax5.hist(x_data, bins = 60, color='black')
ax6.hist(x_data, bins = 70, color='yellow')

plt.show()

# %% [markdown]
# Задание 1.4

# %%
import matplotlib.pyplot as plt
import pandas as pd

heights = [188, 172, 187, 161, 183, 172, 185, 163, 173,
           183, 174, 174, 175, 178, 183, 195, 178, 173,
           174, 183, 174, 181, 250, 180, 170, 175, 182,
           180, 183, 178, 182, 188, 175, 179, 184, 193,
           182, 183, 175, 185, 182, 183, 156, 185, 199]

gender = ['male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'female',
           'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female',
           'female', 'male', 'female', 'male', 'female', 'male', 'female', 'female', 'female',
           'female', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male',
           'male', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'male']

weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73,
           72, 75, 78, 85, 93, 78, 70, 74, 80, 83, 82,
           68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76,
           77, 80, 103, 82, 83, 77, 89, 80, 85, 82, 85, 110]

ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34,
        26, 50, 48, 45, 52, 56, 46, 54, 28, 52, 47,
        55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21,
        62, 43, 55, 56, 61, 53, 22, 64, 45, 54, 47, 38]


df_dict = {'heights': heights, 'gender': gender, 'weights': weights, 'ages': ages}

df = pd.DataFrame(df_dict)

# %%
df.plot(kind = 'scatter',
  x ='heights',
  y ='ages',
  title = 'heights/ages')
# Out:
# c:\Users\KMF\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: title={'center': 'heights/ages'}, xlabel='heights', ylabel='ages'>

# %%
df.plot(kind = 'scatter',
  x ='heights',
  y ='weights',
  title = 'heights/weights')
# Out:
# <AxesSubplot: title={'center': 'heights/weights'}, xlabel='heights', ylabel='weights'>

# %%
df.plot(kind = 'scatter',
  x ='weights',
  y ='ages',
  title = 'weights/ages')
# Out:
# <AxesSubplot: title={'center': 'weights/ages'}, xlabel='weights', ylabel='ages'>

# %%
df['heights'].plot(kind='hist',  title = 'heights', bins=30)
# Out:
# <AxesSubplot: title={'center': 'heights'}, ylabel='Frequency'>

# %%
df.describe()
# Out:
#           heights     weights       ages
# count   45.000000   45.000000  45.000000
# mean   180.844444   80.422222  49.133333
# std     13.297224    8.438249  10.674098
# min    156.000000   64.000000  21.000000
# 25%    174.000000   75.000000  45.000000
# 50%    181.000000   80.000000  53.000000
# 75%    183.000000   84.000000  55.000000
# max    250.000000  110.000000  64.000000

# %%
res_iqr_h = df.describe()['heights']['75%'] - df.describe()['heights']['25%']
res_iqr_w = df.describe()['weights']['75%'] - df.describe()['weights']['25%']
res_iqr_a = df.describe()['ages']['75%'] - df.describe()['ages']['25%']

# %%
q1 = df.heights.quantile(0.25)  # 25-й перцентиль
q3 = df.heights.quantile(0.75)  # 75-й перцентиль
iqr = q3 - q1                         # межквартильный размах
lower_bound = q1 - (iqr*1.5)          # нижняя граница выбросов
upper_bound = q3 + (iqr*1.5)          # верхняя граница выбросов
 
print('25-й перцентиль: {},'.format(q1),
      '75-й перцентиль: {},'.format(q3),
      "IQR: {}, ".format(iqr),
      "Границы выбросов: [{lb}, {ub}].".format(lb=lower_bound, ub=upper_bound))
# Out:
# 25-й перцентиль: 174.0, 75-й перцентиль: 183.0, IQR: 9.0,  Границы выбросов: [160.5, 196.5].

# %%
print(res_iqr_h, res_iqr_w, res_iqr_a)
# Out:
# 9.0 9.0 10.0

# %%
import seaborn as sns
from scipy import stats

norm_rv = stats.norm(loc=30, scale=5)
samples = np.trunc(norm_rv.rvs(365))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
fig.suptitle('Распределение признака feature_0')
histplot = sns.histplot(x=samples, ax=axes[0])
boxplot = sns.boxplot(x=samples, ax=axes[1])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
fig.suptitle('Распределение признака feature_3')
histplot = sns.histplot(x=samples, ax=axes[0])
boxplot = sns.boxplot(x=samples, ax=axes[1])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [110], line 1
# ----> 1 import seaborn as sns
#       2 from scipy import stats
#       4 norm_rv = stats.norm(loc=30, scale=5)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import matplotlib.pyplot as plt
import numpy as np

res_iqr_h = []

plt.style.use('classic')
plt.boxplot (df['heights'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')
plt.boxplot (df['weights'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')
plt.boxplot (df['ages'])
plt.show()
